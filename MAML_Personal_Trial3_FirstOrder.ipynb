# %%
# Dependencies
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as keras_backend
from tensorflow.keras import layers

import random
import sys
import time

from tensorflow.keras import utils
from tensorflow.keras import preprocessing
from os import listdir
from os.path import isdir, join

import numpy as np
import matplotlib.pyplot as plt

# Reproduction
seed = 333
np.random.seed(seed)

# %% [markdown]
# ### Data processing

# %%
from os.path import join
project_path = r"C:\Users\ktub2\Dropbox\family\Kausthubh\UW Madison\Coursework\ECE 539\Project"

# %%
omni_path = join(project_path, r"omniglot-processed-train")
omni_train_datasets = dict()
omni_val_datasets = dict()

for name in listdir(omni_path):
    path = join(omni_path, name)
    if isdir(path):
        omni_train_datasets[name] = preprocessing.image_dataset_from_directory(path, label_mode='categorical',
                                                             color_mode='grayscale', batch_size=1000, image_size=(28,28),
                                                             seed=seed, validation_split=0.25, subset="training")
        omni_val_datasets[name] = preprocessing.image_dataset_from_directory(path, label_mode='categorical',
                                                             color_mode='grayscale', batch_size=1000, image_size=(28,28),
                                                             seed=seed, validation_split=0.25, subset="validation")
# Out:
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.
# Found 400 files belonging to 20 classes.
# Using 300 files for training.
# Found 400 files belonging to 20 classes.
# Using 100 files for validation.

# %%
def dataset_to_tensors(dataset):
    xs = []
    ys = []
    for x, y in dataset:
        xs.extend(x)
        ys.extend(y)
    # xs = np.array(xs)
    # ys = np.array(ys)
    return tf.convert_to_tensor(xs), tf.convert_to_tensor(ys)

xs, ys = dataset_to_tensors(omni_val_datasets['Grantha'])
print(xs.shape, ys.shape)
# Out:
# (100, 28, 28, 1) (100, 20)

# %%
omni_train_data = []
omni_train_labels = []
omni_val_data = []
omni_val_labels = []
for i in omni_train_datasets.keys():
    xs,ys = dataset_to_tensors(omni_train_datasets[i])
    omni_train_data.append(xs)
    omni_train_labels.append(ys)
    print('Train dataset converted')
    xs,ys = dataset_to_tensors(omni_val_datasets[i])
    omni_val_data.append(xs)
    omni_val_labels.append(ys)
    print('Val dataset converted')
# Out:
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted
# Train dataset converted
# Val dataset converted

# %%
complete_datasets = []
for i in range(len(omni_train_data)):
    if(len(omni_val_data[i]) == 100):
        complete_datasets.append( (omni_train_data[i],omni_train_labels[i],omni_val_data[i],omni_val_labels[i]) )

# %% [markdown]
# ### Model definition and relevant functions

# %%
def create_model():
    relu_initializer = tf.keras.initializers.HeNormal()
    softmax_initializer = tf.keras.initializers.GlorotNormal()
    
    inputs = keras.Input(shape=(28,28,1))
    for i in range(4):
        x = layers.Conv2D(64, (3,3), kernel_initializer=relu_initializer, bias_initializer='zeros', 
                          activation='relu', padding='same')(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPool2D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(20, kernel_initializer=softmax_initializer)(x)
    outputs = layers.Softmax()(x)
    
    model = keras.Model(inputs=inputs, outputs=outputs, name='maml_model')
    return model

# %%
def compute_loss(model, x, y, loss_fn=keras.losses.CategoricalCrossentropy()):
    logits = model(x)
    loss = loss_fn(y, logits)
    return loss

# %% [markdown]
# ### Meta Learning

# %%
lr = 0.001
alpha = 0.1
num_tasks = 15
epochs = 1000
inner_epochs = 3
i = 0
optimizer_inner = keras.optimizers.SGD(learning_rate=alpha)
optimizer_outer = keras.optimizers.Adam(learning_rate=lr)

model = create_model()
model.compile()

for epoch in range(epochs):
    all_meta_gradients = []
    total_loss = 0
    
    for task in random.sample(complete_datasets,num_tasks):
        train_data, train_labels, test_data, test_labels = task
        
        with tf.GradientTape() as test_tape:
            model_copy = create_model()
            model_copy.set_weights(model.get_weights())
            model_copy.compile(optimizer=optimizer_inner, loss=tf.keras.losses.CategoricalCrossentropy())
            inner_history = model_copy.fit(train_data, train_labels, epochs=inner_epochs, verbose=0)
            test_loss = compute_loss(model_copy, test_data, test_labels)
            total_loss += test_loss
            i += 1
        print('.',end='')
        meta_gradients = test_tape.gradient(test_loss, model_copy.trainable_weights)
        all_meta_gradients.append(meta_gradients)
      
    print('')
    print('Gradient check: '+str(all_meta_gradients[0][0][0,0,0,0].numpy()))
    sum_meta_gradients = all_meta_gradients[0]
    for i in range(1,len(all_meta_gradients)):
        for j in range(len(all_meta_gradients[i])):
            sum_meta_gradients[j] = sum_meta_gradients[j] + all_meta_gradients[i][j]
    optimizer_outer.apply_gradients(zip(sum_meta_gradients, model.trainable_weights))
    
    print('Meta Update: Epoch Number '+str(epoch))
    print('Avg. Loss: '+str(total_loss/(i+1)))
# Out:
# ...............
# Gradient check: 0.027422095
# Meta Update: Epoch Number 0
# Avg. Loss: tf.Tensor(14.2548895, shape=(), dtype=float32)
# ...............
# Gradient check: 0.00023497517
# Meta Update: Epoch Number 1
# Avg. Loss: tf.Tensor(14.134669, shape=(), dtype=float32)
# ...............
# Gradient check: 0.21215045
# Meta Update: Epoch Number 2
# Avg. Loss: tf.Tensor(14.164075, shape=(), dtype=float32)
# ...............
# Gradient check: 0.11242764
# Meta Update: Epoch Number 3
# Avg. Loss: tf.Tensor(13.886563, shape=(), dtype=float32)
# ...............
# Gradient check: 0.098595545
# Meta Update: Epoch Number 4
# Avg. Loss: tf.Tensor(13.903209, shape=(), dtype=float32)
# ...............
# Gradient check: -0.017359382
# Meta Update: Epoch Number 5
# Avg. Loss: tf.Tensor(13.942461, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 6
# Avg. Loss: tf.Tensor(13.764863, shape=(), dtype=float32)
# ...............
# Gradient check: 0.025217641
# Meta Update: Epoch Number 7
# Avg. Loss: tf.Tensor(14.257921, shape=(), dtype=float32)
# ...............
# Gradient check: 0.038200177
# Meta Update: Epoch Number 8
# Avg. Loss: tf.Tensor(13.957407, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 9
# Avg. Loss: tf.Tensor(14.107369, shape=(), dtype=float32)
# ...............
# Gradient check: 0.023405086
# Meta Update: Epoch Number 10
# Avg. Loss: tf.Tensor(14.149323, shape=(), dtype=float32)
# ...............
# Gradient check: 0.06564471
# Meta Update: Epoch Number 11
# Avg. Loss: tf.Tensor(13.746099, shape=(), dtype=float32)
# ...............
# Gradient check: 0.039100196
# Meta Update: Epoch Number 12
# Avg. Loss: tf.Tensor(13.757275, shape=(), dtype=float32)
# ...............
# Gradient check: 0.049115382
# Meta Update: Epoch Number 13
# Avg. Loss: tf.Tensor(14.080846, shape=(), dtype=float32)
# ...............
# Gradient check: 0.07507213
# Meta Update: Epoch Number 14
# Avg. Loss: tf.Tensor(14.049909, shape=(), dtype=float32)
# ...............
# Gradient check: 0.12494136
# Meta Update: Epoch Number 15
# Avg. Loss: tf.Tensor(14.272524, shape=(), dtype=float32)
# ...............
# Gradient check: -0.00086889823
# Meta Update: Epoch Number 16
# Avg. Loss: tf.Tensor(14.492384, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 17
# Avg. Loss: tf.Tensor(14.361898, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 18
# Avg. Loss: tf.Tensor(13.902314, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 19
# Avg. Loss: tf.Tensor(14.268778, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 20
# Avg. Loss: tf.Tensor(14.152108, shape=(), dtype=float32)
# ...............
# Gradient check: 0.029301252
# Meta Update: Epoch Number 21
# Avg. Loss: tf.Tensor(14.489993, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0044021346
# Meta Update: Epoch Number 22
# Avg. Loss: tf.Tensor(13.836687, shape=(), dtype=float32)
# ...............
# Gradient check: 0.06371163
# Meta Update: Epoch Number 23
# Avg. Loss: tf.Tensor(14.213882, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0030725398
# Meta Update: Epoch Number 24
# Avg. Loss: tf.Tensor(14.036226, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0061223474
# Meta Update: Epoch Number 25
# Avg. Loss: tf.Tensor(14.326448, shape=(), dtype=float32)
# ...............
# Gradient check: -0.037980814
# Meta Update: Epoch Number 26
# Avg. Loss: tf.Tensor(14.652176, shape=(), dtype=float32)
# ...............
# Gradient check: 0.06462508
# Meta Update: Epoch Number 27
# Avg. Loss: tf.Tensor(14.063494, shape=(), dtype=float32)
# ...............
# Gradient check: 0.10934862
# Meta Update: Epoch Number 28
# Avg. Loss: tf.Tensor(13.991626, shape=(), dtype=float32)
# ...............
# Gradient check: 0.049854755
# Meta Update: Epoch Number 29
# Avg. Loss: tf.Tensor(14.3587475, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0026752898
# Meta Update: Epoch Number 30
# Avg. Loss: tf.Tensor(13.940218, shape=(), dtype=float32)
# ...............
# Gradient check: 0.031368688
# Meta Update: Epoch Number 31
# Avg. Loss: tf.Tensor(14.016032, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 32
# Avg. Loss: tf.Tensor(14.166775, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 33
# Avg. Loss: tf.Tensor(14.329467, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 34
# Avg. Loss: tf.Tensor(14.427783, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 35
# Avg. Loss: tf.Tensor(13.785664, shape=(), dtype=float32)
# ...............
# Gradient check: 0.049937632
# Meta Update: Epoch Number 36
# Avg. Loss: tf.Tensor(13.719712, shape=(), dtype=float32)
# ...............
# Gradient check: 0.17820741
# Meta Update: Epoch Number 37
# Avg. Loss: tf.Tensor(14.13316, shape=(), dtype=float32)
# ...............
# Gradient check: 0.01286558
# Meta Update: Epoch Number 38
# Avg. Loss: tf.Tensor(13.699616, shape=(), dtype=float32)
# ...............
# Gradient check: 0.036486086
# Meta Update: Epoch Number 39
# Avg. Loss: tf.Tensor(14.04666, shape=(), dtype=float32)
# ...............
# Gradient check: -0.10362911
# Meta Update: Epoch Number 40
# Avg. Loss: tf.Tensor(13.557541, shape=(), dtype=float32)
# ...............
# Gradient check: 0.047384072
# Meta Update: Epoch Number 41
# Avg. Loss: tf.Tensor(13.755291, shape=(), dtype=float32)
# ...............
# Gradient check: 0.12954642
# Meta Update: Epoch Number 42
# Avg. Loss: tf.Tensor(14.306413, shape=(), dtype=float32)
# ...............
# Gradient check: 0.23029041
# Meta Update: Epoch Number 43
# Avg. Loss: tf.Tensor(14.195469, shape=(), dtype=float32)
# ...............
# Gradient check: 0.07984951
# Meta Update: Epoch Number 44
# Avg. Loss: tf.Tensor(14.055004, shape=(), dtype=float32)
# ...............
# Gradient check: 0.013748931
# Meta Update: Epoch Number 45
# Avg. Loss: tf.Tensor(13.813478, shape=(), dtype=float32)
# ...............
# Gradient check: 0.009428666
# Meta Update: Epoch Number 46
# Avg. Loss: tf.Tensor(13.936002, shape=(), dtype=float32)
# ...............
# Gradient check: 0.098109215
# Meta Update: Epoch Number 47
# Avg. Loss: tf.Tensor(13.940231, shape=(), dtype=float32)
# ...............
# Gradient check: -0.05761823
# Meta Update: Epoch Number 48
# Avg. Loss: tf.Tensor(14.222561, shape=(), dtype=float32)
# ...............
# Gradient check: -0.035743684
# Meta Update: Epoch Number 49
# Avg. Loss: tf.Tensor(13.286161, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 50
# Avg. Loss: tf.Tensor(13.538135, shape=(), dtype=float32)
# ...............
# Gradient check: 0.03234275
# Meta Update: Epoch Number 51
# Avg. Loss: tf.Tensor(13.642705, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 52
# Avg. Loss: tf.Tensor(14.222968, shape=(), dtype=float32)
# ...............
# Gradient check: 0.14039424
# Meta Update: Epoch Number 53
# Avg. Loss: tf.Tensor(14.2221, shape=(), dtype=float32)
# ...............
# Gradient check: 0.03893593
# Meta Update: Epoch Number 54
# Avg. Loss: tf.Tensor(13.672837, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0024596397
# Meta Update: Epoch Number 55
# Avg. Loss: tf.Tensor(13.628833, shape=(), dtype=float32)
# ...............
# Gradient check: 0.13935009
# Meta Update: Epoch Number 56
# Avg. Loss: tf.Tensor(13.956468, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0062807132
# Meta Update: Epoch Number 57
# Avg. Loss: tf.Tensor(13.698839, shape=(), dtype=float32)
# ...............
# Gradient check: 0.02161225
# Meta Update: Epoch Number 58
# Avg. Loss: tf.Tensor(13.883301, shape=(), dtype=float32)
# ...............
# Gradient check: -0.000351161
# Meta Update: Epoch Number 59
# Avg. Loss: tf.Tensor(13.995195, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 60
# Avg. Loss: tf.Tensor(14.207159, shape=(), dtype=float32)
# ...............
# Gradient check: 0.18729728
# Meta Update: Epoch Number 61
# Avg. Loss: tf.Tensor(13.907163, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0019152708
# Meta Update: Epoch Number 62
# Avg. Loss: tf.Tensor(14.079812, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0110787805
# Meta Update: Epoch Number 63
# Avg. Loss: tf.Tensor(13.429934, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 64
# Avg. Loss: tf.Tensor(13.813412, shape=(), dtype=float32)
# ...............
# Gradient check: 0.07400082
# Meta Update: Epoch Number 65
# Avg. Loss: tf.Tensor(13.980189, shape=(), dtype=float32)
# ...............
# Gradient check: -0.029282533
# Meta Update: Epoch Number 66
# Avg. Loss: tf.Tensor(13.754109, shape=(), dtype=float32)
# ...............
# Gradient check: 0.05635599
# Meta Update: Epoch Number 67
# Avg. Loss: tf.Tensor(13.740127, shape=(), dtype=float32)
# ...............
# Gradient check: 0.04662149
# Meta Update: Epoch Number 68
# Avg. Loss: tf.Tensor(13.729827, shape=(), dtype=float32)
# ...............
# Gradient check: 0.09538406
# Meta Update: Epoch Number 69
# Avg. Loss: tf.Tensor(13.943166, shape=(), dtype=float32)
# ...............
# Gradient check: 0.11516012
# Meta Update: Epoch Number 70
# Avg. Loss: tf.Tensor(13.357179, shape=(), dtype=float32)
# ...............
# Gradient check: 0.00023881206
# Meta Update: Epoch Number 71
# Avg. Loss: tf.Tensor(13.481731, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 72
# Avg. Loss: tf.Tensor(13.730345, shape=(), dtype=float32)
# ...............
# Gradient check: 0.025406525
# Meta Update: Epoch Number 73
# Avg. Loss: tf.Tensor(13.816263, shape=(), dtype=float32)
# ...............
# Gradient check: -0.047641836
# Meta Update: Epoch Number 74
# Avg. Loss: tf.Tensor(13.686942, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 75
# Avg. Loss: tf.Tensor(13.5137415, shape=(), dtype=float32)
# ...............
# Gradient check: 0.007232217
# Meta Update: Epoch Number 76
# Avg. Loss: tf.Tensor(13.872525, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 77
# Avg. Loss: tf.Tensor(13.729831, shape=(), dtype=float32)
# ...............
# Gradient check: -0.033124954
# Meta Update: Epoch Number 78
# Avg. Loss: tf.Tensor(14.195163, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0065849964
# Meta Update: Epoch Number 79
# Avg. Loss: tf.Tensor(13.788273, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 80
# Avg. Loss: tf.Tensor(13.572412, shape=(), dtype=float32)
# ...............
# Gradient check: -0.033781588
# Meta Update: Epoch Number 81
# Avg. Loss: tf.Tensor(13.562128, shape=(), dtype=float32)
# ...............
# Gradient check: -0.039614152
# Meta Update: Epoch Number 82
# Avg. Loss: tf.Tensor(13.439879, shape=(), dtype=float32)
# ...............
# Gradient check: -0.013854518
# Meta Update: Epoch Number 83
# Avg. Loss: tf.Tensor(13.727195, shape=(), dtype=float32)
# ...............
# Gradient check: 0.010748474
# Meta Update: Epoch Number 84
# Avg. Loss: tf.Tensor(13.463805, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 85
# Avg. Loss: tf.Tensor(12.783177, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 86
# Avg. Loss: tf.Tensor(13.393361, shape=(), dtype=float32)
# ...............
# Gradient check: -0.044005405
# Meta Update: Epoch Number 87
# Avg. Loss: tf.Tensor(13.296672, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 88
# Avg. Loss: tf.Tensor(12.814163, shape=(), dtype=float32)
# ...............
# Gradient check: 0.00010929347
# Meta Update: Epoch Number 89
# Avg. Loss: tf.Tensor(13.234732, shape=(), dtype=float32)
# ...............
# Gradient check: 0.020759176
# Meta Update: Epoch Number 90
# Avg. Loss: tf.Tensor(13.148826, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 91
# Avg. Loss: tf.Tensor(13.450457, shape=(), dtype=float32)
# ...............
# Gradient check: -0.007891476
# Meta Update: Epoch Number 92
# Avg. Loss: tf.Tensor(12.508134, shape=(), dtype=float32)
# ...............
# Gradient check: -0.038921677
# Meta Update: Epoch Number 93
# Avg. Loss: tf.Tensor(13.534, shape=(), dtype=float32)
# ...............
# Gradient check: -0.064814284
# Meta Update: Epoch Number 94
# Avg. Loss: tf.Tensor(12.463738, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0005662087
# Meta Update: Epoch Number 95
# Avg. Loss: tf.Tensor(13.239344, shape=(), dtype=float32)
# ...............
# Gradient check: -0.118515454
# Meta Update: Epoch Number 96
# Avg. Loss: tf.Tensor(12.474465, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0546647
# Meta Update: Epoch Number 97
# Avg. Loss: tf.Tensor(12.200755, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0083104065
# Meta Update: Epoch Number 98
# Avg. Loss: tf.Tensor(12.995909, shape=(), dtype=float32)
# ...............
# Gradient check: 0.059385266
# Meta Update: Epoch Number 99
# Avg. Loss: tf.Tensor(13.169541, shape=(), dtype=float32)
# ...............
# Gradient check: -0.05476467
# Meta Update: Epoch Number 100
# Avg. Loss: tf.Tensor(12.876862, shape=(), dtype=float32)
# ...............
# Gradient check: 0.02323768
# Meta Update: Epoch Number 101
# Avg. Loss: tf.Tensor(12.89444, shape=(), dtype=float32)
# ...............
# Gradient check: -0.00038025182
# Meta Update: Epoch Number 102
# Avg. Loss: tf.Tensor(12.894625, shape=(), dtype=float32)
# ...............
# Gradient check: 0.007010393
# Meta Update: Epoch Number 103
# Avg. Loss: tf.Tensor(12.180631, shape=(), dtype=float32)
# ...............
# Gradient check: -0.006505644
# Meta Update: Epoch Number 104
# Avg. Loss: tf.Tensor(11.876229, shape=(), dtype=float32)
# ...............
# Gradient check: -0.12372705
# Meta Update: Epoch Number 105
# Avg. Loss: tf.Tensor(12.178498, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 106
# Avg. Loss: tf.Tensor(12.41027, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 107
# Avg. Loss: tf.Tensor(11.427752, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0061240424
# Meta Update: Epoch Number 108
# Avg. Loss: tf.Tensor(12.623976, shape=(), dtype=float32)
# ...............
# Gradient check: -0.010954974
# Meta Update: Epoch Number 109
# Avg. Loss: tf.Tensor(12.294314, shape=(), dtype=float32)
# ...............
# Gradient check: -0.018240478
# Meta Update: Epoch Number 110
# Avg. Loss: tf.Tensor(12.537494, shape=(), dtype=float32)
# ...............
# Gradient check: 0.00039988197
# Meta Update: Epoch Number 111
# Avg. Loss: tf.Tensor(10.888728, shape=(), dtype=float32)
# ...............
# Gradient check: 0.17246649
# Meta Update: Epoch Number 112
# Avg. Loss: tf.Tensor(12.428533, shape=(), dtype=float32)
# ...............
# Gradient check: 0.00016765518
# Meta Update: Epoch Number 113
# Avg. Loss: tf.Tensor(11.128159, shape=(), dtype=float32)
# ...............
# Gradient check: -0.102169484
# Meta Update: Epoch Number 114
# Avg. Loss: tf.Tensor(12.022759, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0006310276
# Meta Update: Epoch Number 115
# Avg. Loss: tf.Tensor(12.728475, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 116
# Avg. Loss: tf.Tensor(12.055043, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0062022973
# Meta Update: Epoch Number 117
# Avg. Loss: tf.Tensor(12.07174, shape=(), dtype=float32)
# ...............
# Gradient check: -0.009849653
# Meta Update: Epoch Number 118
# Avg. Loss: tf.Tensor(12.986881, shape=(), dtype=float32)
# ...............
# Gradient check: 0.34820086
# Meta Update: Epoch Number 119
# Avg. Loss: tf.Tensor(11.497484, shape=(), dtype=float32)
# ...............
# Gradient check: -0.002270747
# Meta Update: Epoch Number 120
# Avg. Loss: tf.Tensor(12.053127, shape=(), dtype=float32)
# ...............
# Gradient check: -0.03309104
# Meta Update: Epoch Number 121
# Avg. Loss: tf.Tensor(11.805314, shape=(), dtype=float32)
# ...............
# Gradient check: 0.018162703
# Meta Update: Epoch Number 122
# Avg. Loss: tf.Tensor(12.593829, shape=(), dtype=float32)
# ...............
# Gradient check: -0.05884634
# Meta Update: Epoch Number 123
# Avg. Loss: tf.Tensor(12.166621, shape=(), dtype=float32)
# ...............
# Gradient check: -3.1932243e-05
# Meta Update: Epoch Number 124
# Avg. Loss: tf.Tensor(11.428196, shape=(), dtype=float32)
# ...............
# Gradient check: 0.00036983384
# Meta Update: Epoch Number 125
# Avg. Loss: tf.Tensor(12.713954, shape=(), dtype=float32)
# ...............
# Gradient check: 0.06497037
# Meta Update: Epoch Number 126
# Avg. Loss: tf.Tensor(11.717267, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0010342412
# Meta Update: Epoch Number 127
# Avg. Loss: tf.Tensor(11.838325, shape=(), dtype=float32)
# ...............
# Gradient check: 0.027903926
# Meta Update: Epoch Number 128
# Avg. Loss: tf.Tensor(12.551792, shape=(), dtype=float32)
# ...............
# Gradient check: -1.7033793e-05
# Meta Update: Epoch Number 129
# Avg. Loss: tf.Tensor(11.641217, shape=(), dtype=float32)
# ...............
# Gradient check: -0.023108598
# Meta Update: Epoch Number 130
# Avg. Loss: tf.Tensor(10.862893, shape=(), dtype=float32)
# ...............
# Gradient check: -0.03413912
# Meta Update: Epoch Number 131
# Avg. Loss: tf.Tensor(12.598458, shape=(), dtype=float32)
# ...............
# Gradient check: -0.002644211
# Meta Update: Epoch Number 132
# Avg. Loss: tf.Tensor(12.017406, shape=(), dtype=float32)
# ...............
# Gradient check: 0.04387481
# Meta Update: Epoch Number 133
# Avg. Loss: tf.Tensor(11.6700535, shape=(), dtype=float32)
# ...............
# Gradient check: -0.013389387
# Meta Update: Epoch Number 134
# Avg. Loss: tf.Tensor(12.972873, shape=(), dtype=float32)
# ...............
# Gradient check: -0.00042616017
# Meta Update: Epoch Number 135
# Avg. Loss: tf.Tensor(12.00992, shape=(), dtype=float32)
# ...............
# Gradient check: -0.008337163
# Meta Update: Epoch Number 136
# Avg. Loss: tf.Tensor(12.119936, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0094228545
# Meta Update: Epoch Number 137
# Avg. Loss: tf.Tensor(12.263066, shape=(), dtype=float32)
# ...............
# Gradient check: -0.25683177
# Meta Update: Epoch Number 138
# Avg. Loss: tf.Tensor(12.2278, shape=(), dtype=float32)
# ...............
# Gradient check: -0.048178226
# Meta Update: Epoch Number 139
# Avg. Loss: tf.Tensor(11.916759, shape=(), dtype=float32)
# ...............
# Gradient check: -0.028198492
# Meta Update: Epoch Number 140
# Avg. Loss: tf.Tensor(11.157229, shape=(), dtype=float32)
# ...............
# Gradient check: -0.03928121
# Meta Update: Epoch Number 141
# Avg. Loss: tf.Tensor(11.186476, shape=(), dtype=float32)
# ...............
# Gradient check: -0.014733399
# Meta Update: Epoch Number 142
# Avg. Loss: tf.Tensor(10.653629, shape=(), dtype=float32)
# ...............
# Gradient check: -0.022097938
# Meta Update: Epoch Number 143
# Avg. Loss: tf.Tensor(11.416538, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 144
# Avg. Loss: tf.Tensor(11.097065, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0061409064
# Meta Update: Epoch Number 145
# Avg. Loss: tf.Tensor(11.988595, shape=(), dtype=float32)
# ...............
# Gradient check: -0.15757796
# Meta Update: Epoch Number 146
# Avg. Loss: tf.Tensor(12.183746, shape=(), dtype=float32)
# ...............
# Gradient check: 0.010925785
# Meta Update: Epoch Number 147
# Avg. Loss: tf.Tensor(11.471326, shape=(), dtype=float32)
# ...............
# Gradient check: 0.24760109
# Meta Update: Epoch Number 148
# Avg. Loss: tf.Tensor(11.059352, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 149
# Avg. Loss: tf.Tensor(11.397887, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0797384
# Meta Update: Epoch Number 150
# Avg. Loss: tf.Tensor(11.892834, shape=(), dtype=float32)
# ...............
# Gradient check: -0.07253358
# Meta Update: Epoch Number 151
# Avg. Loss: tf.Tensor(11.203267, shape=(), dtype=float32)
# ...............
# Gradient check: -0.049952682
# Meta Update: Epoch Number 152
# Avg. Loss: tf.Tensor(11.703635, shape=(), dtype=float32)
# ...............
# Gradient check: -0.068707794
# Meta Update: Epoch Number 153
# Avg. Loss: tf.Tensor(11.355433, shape=(), dtype=float32)
# ...............
# Gradient check: -0.18359807
# Meta Update: Epoch Number 154
# Avg. Loss: tf.Tensor(11.081613, shape=(), dtype=float32)
# ...............
# Gradient check: -0.023863077
# Meta Update: Epoch Number 155
# Avg. Loss: tf.Tensor(11.137289, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 156
# Avg. Loss: tf.Tensor(11.221332, shape=(), dtype=float32)
# ...............
# Gradient check: 0.1466884
# Meta Update: Epoch Number 157
# Avg. Loss: tf.Tensor(11.403672, shape=(), dtype=float32)
# ...............
# Gradient check: 0.037288412
# Meta Update: Epoch Number 158
# Avg. Loss: tf.Tensor(11.751553, shape=(), dtype=float32)
# ...............
# Gradient check: -0.002559932
# Meta Update: Epoch Number 159
# Avg. Loss: tf.Tensor(11.6388445, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 160
# Avg. Loss: tf.Tensor(11.410954, shape=(), dtype=float32)
# ...............
# Gradient check: -1.0890692
# Meta Update: Epoch Number 161
# Avg. Loss: tf.Tensor(11.865402, shape=(), dtype=float32)
# ...............
# Gradient check: -0.009243451
# Meta Update: Epoch Number 162
# Avg. Loss: tf.Tensor(11.073481, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0001090687
# Meta Update: Epoch Number 163
# Avg. Loss: tf.Tensor(11.509473, shape=(), dtype=float32)
# ...............
# Gradient check: 0.07740852
# Meta Update: Epoch Number 164
# Avg. Loss: tf.Tensor(11.0491295, shape=(), dtype=float32)
# ...............
# Gradient check: -0.021076296
# Meta Update: Epoch Number 165
# Avg. Loss: tf.Tensor(10.930969, shape=(), dtype=float32)
# ...............
# Gradient check: -0.09897673
# Meta Update: Epoch Number 166
# Avg. Loss: tf.Tensor(11.94964, shape=(), dtype=float32)
# ...............
# Gradient check: -0.34274697
# Meta Update: Epoch Number 167
# Avg. Loss: tf.Tensor(11.667858, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0013399031
# Meta Update: Epoch Number 168
# Avg. Loss: tf.Tensor(10.702749, shape=(), dtype=float32)
# ...............
# Gradient check: -0.05853714
# Meta Update: Epoch Number 169
# Avg. Loss: tf.Tensor(11.170269, shape=(), dtype=float32)
# ...............
# Gradient check: -0.2475003
# Meta Update: Epoch Number 170
# Avg. Loss: tf.Tensor(10.098301, shape=(), dtype=float32)
# ...............
# Gradient check: -0.02377115
# Meta Update: Epoch Number 171
# Avg. Loss: tf.Tensor(10.48403, shape=(), dtype=float32)
# ...............
# Gradient check: 0.010872109
# Meta Update: Epoch Number 172
# Avg. Loss: tf.Tensor(10.8221035, shape=(), dtype=float32)
# ...............
# Gradient check: -0.09544586
# Meta Update: Epoch Number 173
# Avg. Loss: tf.Tensor(11.209882, shape=(), dtype=float32)
# ...............
# Gradient check: 0.004871582
# Meta Update: Epoch Number 174
# Avg. Loss: tf.Tensor(11.074005, shape=(), dtype=float32)
# ...............
# Gradient check: 0.05284052
# Meta Update: Epoch Number 175
# Avg. Loss: tf.Tensor(11.253477, shape=(), dtype=float32)
# ...............
# Gradient check: 0.014291002
# Meta Update: Epoch Number 176
# Avg. Loss: tf.Tensor(11.491751, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0012616636
# Meta Update: Epoch Number 177
# Avg. Loss: tf.Tensor(11.06851, shape=(), dtype=float32)
# ...............
# Gradient check: -0.009587343
# Meta Update: Epoch Number 178
# Avg. Loss: tf.Tensor(10.785768, shape=(), dtype=float32)
# ...............
# Gradient check: 0.066984534
# Meta Update: Epoch Number 179
# Avg. Loss: tf.Tensor(11.078054, shape=(), dtype=float32)
# ...............
# Gradient check: -7.8542755e-05
# Meta Update: Epoch Number 180
# Avg. Loss: tf.Tensor(10.676804, shape=(), dtype=float32)
# ...............
# Gradient check: -0.00027033553
# Meta Update: Epoch Number 181
# Avg. Loss: tf.Tensor(10.11389, shape=(), dtype=float32)
# ...............
# Gradient check: 0.154991
# Meta Update: Epoch Number 182
# Avg. Loss: tf.Tensor(9.798051, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 183
# Avg. Loss: tf.Tensor(10.217619, shape=(), dtype=float32)
# ...............
# Gradient check: 0.025213892
# Meta Update: Epoch Number 184
# Avg. Loss: tf.Tensor(10.742161, shape=(), dtype=float32)
# ...............
# Gradient check: 0.67045534
# Meta Update: Epoch Number 185
# Avg. Loss: tf.Tensor(11.405779, shape=(), dtype=float32)
# ...............
# Gradient check: -0.08153702
# Meta Update: Epoch Number 186
# Avg. Loss: tf.Tensor(10.08765, shape=(), dtype=float32)
# ...............
# Gradient check: 0.106872305
# Meta Update: Epoch Number 187
# Avg. Loss: tf.Tensor(10.326858, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 188
# Avg. Loss: tf.Tensor(10.028956, shape=(), dtype=float32)
# ...............
# Gradient check: -0.03391743
# Meta Update: Epoch Number 189
# Avg. Loss: tf.Tensor(9.661459, shape=(), dtype=float32)
# ...............
# Gradient check: 0.11676269
# Meta Update: Epoch Number 190
# Avg. Loss: tf.Tensor(10.545026, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0038110262
# Meta Update: Epoch Number 191
# Avg. Loss: tf.Tensor(9.727454, shape=(), dtype=float32)
# ...............
# Gradient check: 0.23437859
# Meta Update: Epoch Number 192
# Avg. Loss: tf.Tensor(9.57741, shape=(), dtype=float32)
# ...............
# Gradient check: -0.20363198
# Meta Update: Epoch Number 193
# Avg. Loss: tf.Tensor(9.789383, shape=(), dtype=float32)
# ...............
# Gradient check: -0.001863813
# Meta Update: Epoch Number 194
# Avg. Loss: tf.Tensor(9.222288, shape=(), dtype=float32)
# ...............
# Gradient check: 0.15988407
# Meta Update: Epoch Number 195
# Avg. Loss: tf.Tensor(8.814728, shape=(), dtype=float32)
# ...............
# Gradient check: 0.031027708
# Meta Update: Epoch Number 196
# Avg. Loss: tf.Tensor(9.06058, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 197
# Avg. Loss: tf.Tensor(11.509184, shape=(), dtype=float32)
# ...............
# Gradient check: -0.13522142
# Meta Update: Epoch Number 198
# Avg. Loss: tf.Tensor(10.40982, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0015905949
# Meta Update: Epoch Number 199
# Avg. Loss: tf.Tensor(9.574063, shape=(), dtype=float32)
# ...............
# Gradient check: 0.020568794
# Meta Update: Epoch Number 200
# Avg. Loss: tf.Tensor(10.30664, shape=(), dtype=float32)
# ...............
# Gradient check: -0.16930574
# Meta Update: Epoch Number 201
# Avg. Loss: tf.Tensor(9.751539, shape=(), dtype=float32)
# ...............
# Gradient check: 0.061095305
# Meta Update: Epoch Number 202
# Avg. Loss: tf.Tensor(9.900152, shape=(), dtype=float32)
# ...............
# Gradient check: -0.019994367
# Meta Update: Epoch Number 203
# Avg. Loss: tf.Tensor(9.985357, shape=(), dtype=float32)
# ...............
# Gradient check: 0.045409247
# Meta Update: Epoch Number 204
# Avg. Loss: tf.Tensor(8.561387, shape=(), dtype=float32)
# ...............
# Gradient check: 0.031120926
# Meta Update: Epoch Number 205
# Avg. Loss: tf.Tensor(8.511704, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0085503645
# Meta Update: Epoch Number 206
# Avg. Loss: tf.Tensor(9.845346, shape=(), dtype=float32)
# ...............
# Gradient check: 7.464174e-05
# Meta Update: Epoch Number 207
# Avg. Loss: tf.Tensor(10.786244, shape=(), dtype=float32)
# ...............
# Gradient check: 6.8238296e-06
# Meta Update: Epoch Number 208
# Avg. Loss: tf.Tensor(9.427578, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 209
# Avg. Loss: tf.Tensor(9.276768, shape=(), dtype=float32)
# ...............
# Gradient check: 0.043290604
# Meta Update: Epoch Number 210
# Avg. Loss: tf.Tensor(9.053632, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0017962155
# Meta Update: Epoch Number 211
# Avg. Loss: tf.Tensor(10.067441, shape=(), dtype=float32)
# ...............
# Gradient check: -0.03845991
# Meta Update: Epoch Number 212
# Avg. Loss: tf.Tensor(9.756295, shape=(), dtype=float32)
# ...............
# Gradient check: -0.009828116
# Meta Update: Epoch Number 213
# Avg. Loss: tf.Tensor(8.02084, shape=(), dtype=float32)
# ...............
# Gradient check: -0.056226343
# Meta Update: Epoch Number 214
# Avg. Loss: tf.Tensor(9.272539, shape=(), dtype=float32)
# ...............
# Gradient check: -0.004749993
# Meta Update: Epoch Number 215
# Avg. Loss: tf.Tensor(7.7430825, shape=(), dtype=float32)
# ...............
# Gradient check: -0.010202739
# Meta Update: Epoch Number 216
# Avg. Loss: tf.Tensor(7.54058, shape=(), dtype=float32)
# ...............
# Gradient check: -0.036925826
# Meta Update: Epoch Number 217
# Avg. Loss: tf.Tensor(7.7650466, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0005943874
# Meta Update: Epoch Number 218
# Avg. Loss: tf.Tensor(8.465073, shape=(), dtype=float32)
# ...............
# Gradient check: 0.029261993
# Meta Update: Epoch Number 219
# Avg. Loss: tf.Tensor(9.467801, shape=(), dtype=float32)
# ...............
# Gradient check: -0.009795592
# Meta Update: Epoch Number 220
# Avg. Loss: tf.Tensor(9.582739, shape=(), dtype=float32)
# ...............
# Gradient check: 0.004671775
# Meta Update: Epoch Number 221
# Avg. Loss: tf.Tensor(8.837586, shape=(), dtype=float32)
# ...............
# Gradient check: -0.21363842
# Meta Update: Epoch Number 222
# Avg. Loss: tf.Tensor(9.744733, shape=(), dtype=float32)
# ...............
# Gradient check: -0.021276517
# Meta Update: Epoch Number 223
# Avg. Loss: tf.Tensor(9.577391, shape=(), dtype=float32)
# ...............
# Gradient check: -0.05299355
# Meta Update: Epoch Number 224
# Avg. Loss: tf.Tensor(9.849097, shape=(), dtype=float32)
# ...............
# Gradient check: 0.013994425
# Meta Update: Epoch Number 225
# Avg. Loss: tf.Tensor(8.962092, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 226
# Avg. Loss: tf.Tensor(9.266406, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0014330518
# Meta Update: Epoch Number 227
# Avg. Loss: tf.Tensor(9.472494, shape=(), dtype=float32)
# ...............
# Gradient check: -0.14549476
# Meta Update: Epoch Number 228
# Avg. Loss: tf.Tensor(9.304075, shape=(), dtype=float32)
# ...............
# Gradient check: -0.02124513
# Meta Update: Epoch Number 229
# Avg. Loss: tf.Tensor(9.002748, shape=(), dtype=float32)
# ...............
# Gradient check: 0.020641007
# Meta Update: Epoch Number 230
# Avg. Loss: tf.Tensor(8.530107, shape=(), dtype=float32)
# ...............
# Gradient check: -0.96787584
# Meta Update: Epoch Number 231
# Avg. Loss: tf.Tensor(8.55548, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 232
# Avg. Loss: tf.Tensor(9.62466, shape=(), dtype=float32)
# ...............
# Gradient check: -0.08691363
# Meta Update: Epoch Number 233
# Avg. Loss: tf.Tensor(8.608825, shape=(), dtype=float32)
# ...............
# Gradient check: -0.02394611
# Meta Update: Epoch Number 234
# Avg. Loss: tf.Tensor(8.7100725, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 235
# Avg. Loss: tf.Tensor(8.951547, shape=(), dtype=float32)
# ...............
# Gradient check: -0.23781899
# Meta Update: Epoch Number 236
# Avg. Loss: tf.Tensor(9.0114355, shape=(), dtype=float32)
# ...............
# Gradient check: -0.15885681
# Meta Update: Epoch Number 237
# Avg. Loss: tf.Tensor(6.743227, shape=(), dtype=float32)
# ...............
# Gradient check: -0.011389925
# Meta Update: Epoch Number 238
# Avg. Loss: tf.Tensor(9.493012, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0021966123
# Meta Update: Epoch Number 239
# Avg. Loss: tf.Tensor(9.796023, shape=(), dtype=float32)
# ...............
# Gradient check: 0.01124226
# Meta Update: Epoch Number 240
# Avg. Loss: tf.Tensor(7.972539, shape=(), dtype=float32)
# ...............
# Gradient check: -0.042249117
# Meta Update: Epoch Number 241
# Avg. Loss: tf.Tensor(9.432668, shape=(), dtype=float32)
# ...............
# Gradient check: -0.056058906
# Meta Update: Epoch Number 242
# Avg. Loss: tf.Tensor(8.56282, shape=(), dtype=float32)
# ...............
# Gradient check: 0.05351299
# Meta Update: Epoch Number 243
# Avg. Loss: tf.Tensor(9.463072, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0999477
# Meta Update: Epoch Number 244
# Avg. Loss: tf.Tensor(9.380205, shape=(), dtype=float32)
# ...............
# Gradient check: -0.047350325
# Meta Update: Epoch Number 245
# Avg. Loss: tf.Tensor(8.097212, shape=(), dtype=float32)
# ...............
# Gradient check: 0.049723893
# Meta Update: Epoch Number 246
# Avg. Loss: tf.Tensor(8.881429, shape=(), dtype=float32)
# ...............
# Gradient check: 0.21462189
# Meta Update: Epoch Number 247
# Avg. Loss: tf.Tensor(9.202271, shape=(), dtype=float32)
# ...............
# Gradient check: 0.2888583
# Meta Update: Epoch Number 248
# Avg. Loss: tf.Tensor(8.05165, shape=(), dtype=float32)
# ...............
# Gradient check: -0.00011154586
# Meta Update: Epoch Number 249
# Avg. Loss: tf.Tensor(9.03747, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0039200955
# Meta Update: Epoch Number 250
# Avg. Loss: tf.Tensor(9.313984, shape=(), dtype=float32)
# ...............
# Gradient check: -3.9628037e-05
# Meta Update: Epoch Number 251
# Avg. Loss: tf.Tensor(8.302636, shape=(), dtype=float32)
# ...............
# Gradient check: -0.4142709
# Meta Update: Epoch Number 252
# Avg. Loss: tf.Tensor(9.48139, shape=(), dtype=float32)
# ...............
# Gradient check: -0.03985966
# Meta Update: Epoch Number 253
# Avg. Loss: tf.Tensor(9.122733, shape=(), dtype=float32)
# ...............
# Gradient check: -0.30699646
# Meta Update: Epoch Number 254
# Avg. Loss: tf.Tensor(8.727053, shape=(), dtype=float32)
# ...............
# Gradient check: -0.06597738
# Meta Update: Epoch Number 255
# Avg. Loss: tf.Tensor(9.224429, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0850343
# Meta Update: Epoch Number 256
# Avg. Loss: tf.Tensor(8.50832, shape=(), dtype=float32)
# ...............
# Gradient check: -0.05938028
# Meta Update: Epoch Number 257
# Avg. Loss: tf.Tensor(7.955424, shape=(), dtype=float32)
# ...............
# Gradient check: -0.1376755
# Meta Update: Epoch Number 258
# Avg. Loss: tf.Tensor(9.601846, shape=(), dtype=float32)
# ...............
# Gradient check: -0.105711944
# Meta Update: Epoch Number 259
# Avg. Loss: tf.Tensor(8.667279, shape=(), dtype=float32)
# ...............
# Gradient check: -1.1022784e-05
# Meta Update: Epoch Number 260
# Avg. Loss: tf.Tensor(8.066893, shape=(), dtype=float32)
# ...............
# Gradient check: -0.21784297
# Meta Update: Epoch Number 261
# Avg. Loss: tf.Tensor(8.906478, shape=(), dtype=float32)
# ...............
# Gradient check: -0.14379759
# Meta Update: Epoch Number 262
# Avg. Loss: tf.Tensor(9.914926, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0056652687
# Meta Update: Epoch Number 263
# Avg. Loss: tf.Tensor(7.4581084, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 264
# Avg. Loss: tf.Tensor(7.802065, shape=(), dtype=float32)
# ...............
# Gradient check: -0.04536157
# Meta Update: Epoch Number 265
# Avg. Loss: tf.Tensor(9.715607, shape=(), dtype=float32)
# ...............
# Gradient check: 0.028345117
# Meta Update: Epoch Number 266
# Avg. Loss: tf.Tensor(8.101818, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 267
# Avg. Loss: tf.Tensor(10.382452, shape=(), dtype=float32)
# ...............
# Gradient check: -0.09149581
# Meta Update: Epoch Number 268
# Avg. Loss: tf.Tensor(9.988173, shape=(), dtype=float32)
# ...............
# Gradient check: 0.10780354
# Meta Update: Epoch Number 269
# Avg. Loss: tf.Tensor(8.748429, shape=(), dtype=float32)
# ...............
# Gradient check: -0.10694521
# Meta Update: Epoch Number 270
# Avg. Loss: tf.Tensor(8.310116, shape=(), dtype=float32)
# ...............
# Gradient check: -0.037708733
# Meta Update: Epoch Number 271
# Avg. Loss: tf.Tensor(7.517371, shape=(), dtype=float32)
# ...............
# Gradient check: 0.059420753
# Meta Update: Epoch Number 272
# Avg. Loss: tf.Tensor(9.077134, shape=(), dtype=float32)
# ...............
# Gradient check: 0.006154081
# Meta Update: Epoch Number 273
# Avg. Loss: tf.Tensor(9.764844, shape=(), dtype=float32)
# ...............
# Gradient check: -0.1963461
# Meta Update: Epoch Number 274
# Avg. Loss: tf.Tensor(8.865043, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 275
# Avg. Loss: tf.Tensor(9.520209, shape=(), dtype=float32)
# ...............
# Gradient check: -0.21112159
# Meta Update: Epoch Number 276
# Avg. Loss: tf.Tensor(7.690851, shape=(), dtype=float32)
# ...............
# Gradient check: -0.31287107
# Meta Update: Epoch Number 277
# Avg. Loss: tf.Tensor(9.385517, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0006931424
# Meta Update: Epoch Number 278
# Avg. Loss: tf.Tensor(11.273589, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 279
# Avg. Loss: tf.Tensor(9.543597, shape=(), dtype=float32)
# ...............
# Gradient check: -0.008317012
# Meta Update: Epoch Number 280
# Avg. Loss: tf.Tensor(9.702343, shape=(), dtype=float32)
# ...............
# Gradient check: -0.044377644
# Meta Update: Epoch Number 281
# Avg. Loss: tf.Tensor(10.780008, shape=(), dtype=float32)
# ...............
# Gradient check: -0.11012067
# Meta Update: Epoch Number 282
# Avg. Loss: tf.Tensor(10.081762, shape=(), dtype=float32)
# ...............
# Gradient check: 0.118500054
# Meta Update: Epoch Number 283
# Avg. Loss: tf.Tensor(9.340374, shape=(), dtype=float32)
# ...............
# Gradient check: -0.009165805
# Meta Update: Epoch Number 284
# Avg. Loss: tf.Tensor(10.830762, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 285
# Avg. Loss: tf.Tensor(9.861487, shape=(), dtype=float32)
# ...............
# Gradient check: 0.30401033
# Meta Update: Epoch Number 286
# Avg. Loss: tf.Tensor(11.299213, shape=(), dtype=float32)
# ...............
# Gradient check: -0.0018020179
# Meta Update: Epoch Number 287
# Avg. Loss: tf.Tensor(10.859218, shape=(), dtype=float32)
# ...............
# Gradient check: -0.475493
# Meta Update: Epoch Number 288
# Avg. Loss: tf.Tensor(8.86305, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 289
# Avg. Loss: tf.Tensor(12.019731, shape=(), dtype=float32)
# ...............
# Gradient check: 0.00047065437
# Meta Update: Epoch Number 290
# Avg. Loss: tf.Tensor(9.339854, shape=(), dtype=float32)
# ...............
# Gradient check: 0.093382284
# Meta Update: Epoch Number 291
# Avg. Loss: tf.Tensor(9.32162, shape=(), dtype=float32)
# ...............
# Gradient check: 0.22769883
# Meta Update: Epoch Number 292
# Avg. Loss: tf.Tensor(9.896962, shape=(), dtype=float32)
# ...............
# Gradient check: -0.10431857
# Meta Update: Epoch Number 293
# Avg. Loss: tf.Tensor(10.415525, shape=(), dtype=float32)
# ...............
# Gradient check: 0.108925164
# Meta Update: Epoch Number 294
# Avg. Loss: tf.Tensor(11.243511, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 295
# Avg. Loss: tf.Tensor(10.696384, shape=(), dtype=float32)
# ...............
# Gradient check: 0.002429302
# Meta Update: Epoch Number 296
# Avg. Loss: tf.Tensor(11.324838, shape=(), dtype=float32)
# ...............
# Gradient check: 0.07835729
# Meta Update: Epoch Number 297
# Avg. Loss: tf.Tensor(10.899204, shape=(), dtype=float32)
# ...............
# Gradient check: 0.04668823
# Meta Update: Epoch Number 298
# Avg. Loss: tf.Tensor(9.086283, shape=(), dtype=float32)
# ...............
# Gradient check: 0.00032218537
# Meta Update: Epoch Number 299
# Avg. Loss: tf.Tensor(10.404271, shape=(), dtype=float32)
# ...............
# Gradient check: 0.11182245
# Meta Update: Epoch Number 300
# Avg. Loss: tf.Tensor(10.791931, shape=(), dtype=float32)
# ...............
# Gradient check: -0.056810413
# Meta Update: Epoch Number 301
# Avg. Loss: tf.Tensor(9.96034, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 302
# Avg. Loss: tf.Tensor(10.390823, shape=(), dtype=float32)
# ...............
# Gradient check: -0.053936765
# Meta Update: Epoch Number 303
# Avg. Loss: tf.Tensor(11.083698, shape=(), dtype=float32)
# ...............
# Gradient check: -0.628602
# Meta Update: Epoch Number 304
# Avg. Loss: tf.Tensor(11.535549, shape=(), dtype=float32)
# ...............
# Gradient check: -0.069092885
# Meta Update: Epoch Number 305
# Avg. Loss: tf.Tensor(11.190824, shape=(), dtype=float32)
# ...............
# Gradient check: -0.003820606
# Meta Update: Epoch Number 306
# Avg. Loss: tf.Tensor(11.91583, shape=(), dtype=float32)
# ...............
# Gradient check: -0.017815724
# Meta Update: Epoch Number 307
# Avg. Loss: tf.Tensor(12.248971, shape=(), dtype=float32)
# ...............
# Gradient check: 0.2030068
# Meta Update: Epoch Number 308
# Avg. Loss: tf.Tensor(11.937, shape=(), dtype=float32)
# ...............
# Gradient check: 0.028995551
# Meta Update: Epoch Number 309
# Avg. Loss: tf.Tensor(12.8879175, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 310
# Avg. Loss: tf.Tensor(13.783385, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 311
# Avg. Loss: tf.Tensor(11.780097, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 312
# Avg. Loss: tf.Tensor(13.621957, shape=(), dtype=float32)
# ...............
# Gradient check: -0.02422865
# Meta Update: Epoch Number 313
# Avg. Loss: tf.Tensor(13.239095, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 314
# Avg. Loss: tf.Tensor(12.860306, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 315
# Avg. Loss: tf.Tensor(13.655529, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 316
# Avg. Loss: tf.Tensor(14.16843, shape=(), dtype=float32)
# ...............
# Gradient check: 0.031879634
# Meta Update: Epoch Number 317
# Avg. Loss: tf.Tensor(13.134545, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 318
# Avg. Loss: tf.Tensor(13.522351, shape=(), dtype=float32)
# ...............
# Gradient check: -0.017673219
# Meta Update: Epoch Number 319
# Avg. Loss: tf.Tensor(13.707903, shape=(), dtype=float32)
# ...............
# Gradient check: 0.0
# Meta Update: Epoch Number 320
# Avg. Loss: tf.Tensor(14.261331, shape=(), dtype=float32)
# .......
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d7719aff8809> in <module>
#      22             model_copy.set_weights(model.get_weights())
#      23             model_copy.compile(optimizer=optimizer_inner, loss=tf.keras.losses.CategoricalCrossentropy())
# ---> 24             inner_history = model_copy.fit(train_data, train_labels, epochs=inner_epochs, verbose=0)
#      25             test_loss = compute_loss(model_copy, test_data, test_labels)
#      26             total_loss += test_loss
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1929     forward_function, args_with_tangents = forward_backward.forward()
#    1930     if executing_eagerly:
# -> 1931       flat_outputs = forward_function.call(
#    1932           ctx, args_with_tangents,
#    1933           cancellation_manager=cancellation_manager)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Fine-tuning

# %%
omni_test_path = join(project_path, r"omniglot-processed-test")
omni_test_train_datasets = dict()
omni_test_val_datasets = dict()

for name in listdir(omni_test_path):
    path = join(omni_test_path, name)
    if isdir(path):
        omni_test_train_datasets[name] = preprocessing.image_dataset_from_directory(path, label_mode='categorical',
                                                             color_mode='grayscale', batch_size=1000, image_size=(28,28),
                                                             seed=seed, validation_split=0.75, subset="training")
        omni_test_val_datasets[name] = preprocessing.image_dataset_from_directory(path, label_mode='categorical',
                                                             color_mode='grayscale', batch_size=1000, image_size=(28,28),
                                                             seed=seed, validation_split=0.75, subset="validation")
# Out:
# Found 400 files belonging to 20 classes.
# Using 100 files for training.
# Found 400 files belonging to 20 classes.
# Using 300 files for validation.
# Found 400 files belonging to 20 classes.
# Using 100 files for training.
# Found 400 files belonging to 20 classes.
# Using 300 files for validation.
# Found 400 files belonging to 20 classes.
# Using 100 files for training.
# Found 400 files belonging to 20 classes.
# Using 300 files for validation.

# %%
omni_test_train_data = []
omni_test_train_labels = []
omni_test_val_data = []
omni_test_val_labels = []

for i in omni_test_train_datasets.keys():
    xs,ys = dataset_to_tensors(omni_test_train_datasets[i])
    omni_test_train_data.append(xs)
    omni_test_train_labels.append(ys)
    print('Test train dataset converted')
    xs,ys = dataset_to_tensors(omni_test_val_datasets[i])
    omni_test_val_data.append(xs)
    omni_test_val_labels.append(ys)
    print('Test val dataset converted')
# Out:
# Test train dataset converted
# Test val dataset converted
# Test train dataset converted
# Test val dataset converted
# Test train dataset converted
# Test val dataset converted

# %%
greek_fine_tuning_data = omni_test_train_data[0]
greek_fine_tuning_labels = omni_test_train_labels[0]

greek_val_data = omni_test_val_data[0]
greek_val_labels = omni_test_val_labels[0]

model_greek = create_model()
model_greek.set_weights(model.get_weights())

# %%
model_greek.compile(optimizer=keras.optimizers.Adam(learning_rate=0.005),
                    loss=tf.keras.losses.CategoricalCrossentropy(), metrics='accuracy')
model_greek.fit(greek_fine_tuning_data, greek_fine_tuning_labels, epochs=200, verbose=0)

# %%
model_greek.evaluate(greek_val_data, greek_val_labels)
# Out:
# 10/10 [==============================] - 1s 51ms/step - loss: 29.5891 - accuracy: 0.3433
# [29.5891170501709, 0.34333333373069763]

# %%
model_greek_meow = create_model()
model_greek_meow.compile(optimizer=keras.optimizers.Adam(learning_rate=0.005),
                    loss=tf.keras.losses.CategoricalCrossentropy(), metrics='accuracy')
model_greek_meow.fit(greek_fine_tuning_data, greek_fine_tuning_labels, epochs=200, verbose=0)

# %%
model_greek_meow.evaluate(greek_val_data, greek_val_labels)
# Out:
# 10/10 [==============================] - 1s 50ms/step - loss: 22.0064 - accuracy: 0.3233
# [22.00643539428711, 0.3233333230018616]
